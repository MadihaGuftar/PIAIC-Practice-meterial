# %% [markdown]
# # Car Price Prediction::

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/hellbuoy/car-price-prediction

# %% [markdown]
# # Problem Statement::

# %%
# mount google drive in to your Colab enviornment
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/DL Assignments
# Out:
# /content/drive/MyDrive/DL Assignments

# %% [markdown]
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# Which variables are significant in predicting the price of a car
# How well those variables describe the price of a car
# Based on various market surveys, the consulting firm has gathered a large data set of different types of cars across the America market.
#
# # task::
# We are required to model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.

# %% [markdown]
# # WORKFLOW ::

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 4.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 5.Compilation Step (Note : Its a Regression problem , select loss , metrics according to it)
# 6.Train the Model with Epochs (100) and validate it
#
# 7.If the model gets overfit tune your model by changing the units , No. of layers , activation function , epochs , add dropout layer or add Regularizer according to the need .
#
# 8.Evaluation Step
#
# 9.Prediction

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
car_data = pd.read_csv('/content/drive/MyDrive/DL Assignments/CarPrice_Assignment.csv')

# %%
car_data.head()
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.0
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3       4          2               audi 100 ls  ...      24         30  13950.0
# 4       5          2                audi 100ls  ...      18         22  17450.0
#
# [5 rows x 26 columns]

# %%
car_data['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
#check if there are empty cells, if there are then row and column indexes will be returned where values are empty or missing
np.where(car_data.applymap(lambda x: x ==''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
car_data.isnull().any()
# Out:
# car_ID              False
# symboling           False
# CarName             False
# fueltype            False
# aspiration          False
# doornumber          False
# carbody             False
# drivewheel          False
# enginelocation      False
# wheelbase           False
# carlength           False
# carwidth            False
# carheight           False
# curbweight          False
# enginetype          False
# cylindernumber      False
# enginesize          False
# fuelsystem          False
# boreratio           False
# stroke              False
# compressionratio    False
# horsepower          False
# peakrpm             False
# citympg             False
# highwaympg          False
# price               False
# dtype: bool

# %%
# correct the name error in audi 100 ls
car_data.iloc[3,2] = 'audi 100ls'

# %%
car_data.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
car_data.drop(columns=['car_ID'], inplace = True)

# %%
# get column names so that we can use them for one-hot encoding of catagorical featrues in next cell
car_data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
# one-hot encode all catagorical columns
final_car = pd.get_dummies(car_data, columns=['CarName','symboling','fueltype',	'aspiration',	'doornumber',	'carbody',	'drivewheel',	'enginelocation',	'enginetype',	'cylindernumber',	'fuelsystem'], drop_first = True)

# %%
final_car.head()
# Out:
#    wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0       88.6      168.8  ...                0                0
# 1       88.6      168.8  ...                0                0
# 2       94.5      171.2  ...                0                0
# 3       99.8      176.6  ...                0                0
# 4       99.4      176.6  ...                0                0
#
# [5 rows x 193 columns]

# %%
#check statistical data to see abnormal values and outliers
final_car.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  205.000000  205.000000  ...       205.000000       205.000000
# mean    98.756585  174.049268  ...         0.043902         0.004878
# std      6.021776   12.337289  ...         0.205380         0.069843
# min     86.600000  141.100000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     97.000000  173.200000  ...         0.000000         0.000000
# 75%    102.400000  183.100000  ...         0.000000         0.000000
# max    120.900000  208.100000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
#initialize a seed value so that each time we can get the same random number sequence, it will help us  as a team
# working on a common project to work on the same random data. Each new seed will generate a particular sequnce
#of random number. You can choose any seed value here of your choice
# 0.72 means we have taken 72% values for training set as we will make 72/4 = 18 rows of k fold validation data, where
# value of k will be 4 when we compile and fit our model for validation
np.random.seed(11111)
msk = np.random.rand(len(final_car)) < 0.72
train_total = final_car[msk]
test_total = final_car[~msk]

# %%
#check the length of our test and train datasets
print(len(train_total))
print(len(test_total))
# Out:
# 141
# 64

# %%
train_total.head(10)
# Out:
#     wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1        88.6      168.8  ...                0                0
# 2        94.5      171.2  ...                0                0
# 3        99.8      176.6  ...                0                0
# 4        99.4      176.6  ...                0                0
# 5        99.8      177.3  ...                0                0
# 6       105.8      192.7  ...                0                0
# 7       105.8      192.7  ...                0                0
# 8       105.8      192.7  ...                0                0
# 9        99.5      178.2  ...                0                0
# 11      101.2      176.8  ...                0                0
#
# [10 rows x 193 columns]

# %%
# check statistical overview if there are some outliers and abnormal values
train_total.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  141.000000  141.000000  ...       141.000000       141.000000
# mean    98.692199  173.658156  ...         0.035461         0.007092
# std      6.005665   12.320089  ...         0.185601         0.084215
# min     86.600000  144.600000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     96.500000  172.400000  ...         0.000000         0.000000
# 75%    102.400000  180.300000  ...         0.000000         0.000000
# max    115.600000  202.600000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
print(train_total.dtypes)
# Out:
# wheelbase          float64
# carlength          float64
# carwidth           float64
# carheight          float64
# curbweight           int64
#                     ...
# fuelsystem_idi       uint8
# fuelsystem_mfi       uint8
# fuelsystem_mpfi      uint8
# fuelsystem_spdi      uint8
# fuelsystem_spfi      uint8
# Length: 193, dtype: object

# %%
# get our price labels and store in another dataframe
train_label = train_total.loc[:,'price']
test_label = test_total.loc[:,'price']

# %%
train_label
# Out:
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
# 5      15250.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 141, dtype: float64

# %%
# drop price from oroginal training and test dataset , as price is not needed there
test_data= test_total.drop(columns = ['price'])
train_data= train_total.drop(columns = ['price'])

# %%
train_data.shape
# Out:
# (141, 192)

# %%
train_data
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1         88.6      168.8  ...                0                0
# 2         94.5      171.2  ...                0                0
# 3         99.8      176.6  ...                0                0
# 4         99.4      176.6  ...                0                0
# 5         99.8      177.3  ...                0                0
# ..         ...        ...  ...              ...              ...
# 200      109.1      188.8  ...                0                0
# 201      109.1      188.8  ...                0                0
# 202      109.1      188.8  ...                0                0
# 203      109.1      188.8  ...                0                0
# 204      109.1      188.8  ...                0                0
#
# [141 rows x 192 columns]

# %%
#get indices of the columns so that we can know how many columns we have to normalize, as catagorical columns which we
# have added with onehot encoding, do not need to be normalized.. normalizing will be done in next cell
{train_data.columns.get_loc(c): c for idx, c in enumerate(train_data.columns)}
# Out:
# {0: 'wheelbase',
#  1: 'carlength',
#  2: 'carwidth',
#  3: 'carheight',
#  4: 'curbweight',
#  5: 'enginesize',
#  6: 'boreratio',
#  7: 'stroke',
#  8: 'compressionratio',
#  9: 'horsepower',
#  10: 'peakrpm',
#  11: 'citympg',
#  12: 'highwaympg',
#  13: 'CarName_alfa-romero Quadrifoglio',
#  14: 'CarName_alfa-romero giulia',
#  15: 'CarName_alfa-romero stelvio',
#  16: 'CarName_audi 100ls',
#  17: 'CarName_audi 4000',
#  18: 'CarName_audi 5000',
#  19: 'CarName_audi 5000s (diesel)',
#  20: 'CarName_audi fox',
#  21: 'CarName_bmw 320i',
#  22: 'CarName_bmw x1',
#  23: 'CarName_bmw x3',
#  24: 'CarName_bmw x4',
#  25: 'CarName_bmw x5',
#  26: 'CarName_bmw z4',
#  27: 'CarName_buick century',
#  28: 'CarName_buick century luxus (sw)',
#  29: 'CarName_buick century special',
#  30: 'CarName_buick electra 225 custom',
#  31: 'CarName_buick opel isuzu deluxe',
#  32: 'CarName_buick regal sport coupe (turbo)',
#  33: 'CarName_buick skyhawk',
#  34: 'CarName_buick skylark',
#  35: 'CarName_chevrolet impala',
#  36: 'CarName_chevrolet monte carlo',
#  37: 'CarName_chevrolet vega 2300',
#  38: 'CarName_dodge challenger se',
#  39: 'CarName_dodge colt (sw)',
#  40: 'CarName_dodge colt hardtop',
#  41: 'CarName_dodge coronet custom',
#  42: 'CarName_dodge coronet custom (sw)',
#  43: 'CarName_dodge d200',
#  44: 'CarName_dodge dart custom',
#  45: 'CarName_dodge monaco (sw)',
#  46: 'CarName_dodge rampage',
#  47: 'CarName_honda accord',
#  48: 'CarName_honda accord cvcc',
#  49: 'CarName_honda accord lx',
#  50: 'CarName_honda civic',
#  51: 'CarName_honda civic (auto)',
#  52: 'CarName_honda civic 1300',
#  53: 'CarName_honda civic 1500 gl',
#  54: 'CarName_honda civic cvcc',
#  55: 'CarName_honda prelude',
#  56: 'CarName_isuzu D-Max ',
#  57: 'CarName_isuzu D-Max V-Cross',
#  58: 'CarName_isuzu MU-X',
#  59: 'CarName_jaguar xf',
#  60: 'CarName_jaguar xj',
#  61: 'CarName_jaguar xk',
#  62: 'CarName_maxda glc deluxe',
#  63: 'CarName_maxda rx3',
#  64: 'CarName_mazda 626',
#  65: 'CarName_mazda glc',
#  66: 'CarName_mazda glc 4',
#  67: 'CarName_mazda glc custom',
#  68: 'CarName_mazda glc custom l',
#  69: 'CarName_mazda glc deluxe',
#  70: 'CarName_mazda rx-4',
#  71: 'CarName_mazda rx-7 gs',
#  72: 'CarName_mazda rx2 coupe',
#  73: 'CarName_mercury cougar',
#  74: 'CarName_mitsubishi g4',
#  75: 'CarName_mitsubishi lancer',
#  76: 'CarName_mitsubishi mirage',
#  77: 'CarName_mitsubishi mirage g4',
#  78: 'CarName_mitsubishi montero',
#  79: 'CarName_mitsubishi outlander',
#  80: 'CarName_mitsubishi pajero',
#  81: 'CarName_nissan clipper',
#  82: 'CarName_nissan dayz',
#  83: 'CarName_nissan fuga',
#  84: 'CarName_nissan gt-r',
#  85: 'CarName_nissan juke',
#  86: 'CarName_nissan kicks',
#  87: 'CarName_nissan latio',
#  88: 'CarName_nissan leaf',
#  89: 'CarName_nissan note',
#  90: 'CarName_nissan nv200',
#  91: 'CarName_nissan otti',
#  92: 'CarName_nissan rogue',
#  93: 'CarName_nissan teana',
#  94: 'CarName_nissan titan',
#  95: 'CarName_peugeot 304',
#  96: 'CarName_peugeot 504',
#  97: 'CarName_peugeot 504 (sw)',
#  98: 'CarName_peugeot 505s turbo diesel',
#  99: 'CarName_peugeot 604sl',
#  100: 'CarName_plymouth cricket',
#  101: 'CarName_plymouth duster',
#  102: 'CarName_plymouth fury gran sedan',
#  103: 'CarName_plymouth fury iii',
#  104: 'CarName_plymouth satellite custom (sw)',
#  105: 'CarName_plymouth valiant',
#  106: 'CarName_porcshce panamera',
#  107: 'CarName_porsche boxter',
#  108: 'CarName_porsche cayenne',
#  109: 'CarName_porsche macan',
#  110: 'CarName_renault 12tl',
#  111: 'CarName_renault 5 gtl',
#  112: 'CarName_saab 99e',
#  113: 'CarName_saab 99gle',
#  114: 'CarName_saab 99le',
#  115: 'CarName_subaru',
#  116: 'CarName_subaru baja',
#  117: 'CarName_subaru brz',
#  118: 'CarName_subaru dl',
#  119: 'CarName_subaru r1',
#  120: 'CarName_subaru r2',
#  121: 'CarName_subaru trezia',
#  122: 'CarName_subaru tribeca',
#  123: 'CarName_toyota carina',
#  124: 'CarName_toyota celica gt',
#  125: 'CarName_toyota celica gt liftback',
#  126: 'CarName_toyota corolla',
#  127: 'CarName_toyota corolla 1200',
#  128: 'CarName_toyota corolla 1600 (sw)',
#  129: 'CarName_toyota corolla liftback',
#  130: 'CarName_toyota corolla tercel',
#  131: 'CarName_toyota corona',
#  132: 'CarName_toyota corona hardtop',
#  133: 'CarName_toyota corona liftback',
#  134: 'CarName_toyota corona mark ii',
#  135: 'CarName_toyota cressida',
#  136: 'CarName_toyota mark ii',
#  137: 'CarName_toyota starlet',
#  138: 'CarName_toyota tercel',
#  139: 'CarName_toyouta tercel',
#  140: 'CarName_vokswagen rabbit',
#  141: 'CarName_volkswagen 1131 deluxe sedan',
#  142: 'CarName_volkswagen 411 (sw)',
#  143: 'CarName_volkswagen dasher',
#  144: 'CarName_volkswagen model 111',
#  145: 'CarName_volkswagen rabbit',
#  146: 'CarName_volkswagen rabbit custom',
#  147: 'CarName_volkswagen super beetle',
#  148: 'CarName_volkswagen type 3',
#  149: 'CarName_volvo 144ea',
#  150: 'CarName_volvo 145e (sw)',
#  151: 'CarName_volvo 244dl',
#  152: 'CarName_volvo 245',
#  153: 'CarName_volvo 246',
#  154: 'CarName_volvo 264gl',
#  155: 'CarName_volvo diesel',
#  156: 'CarName_vw dasher',
#  157: 'CarName_vw rabbit',
#  158: 'symboling_-1',
#  159: 'symboling_0',
#  160: 'symboling_1',
#  161: 'symboling_2',
#  162: 'symboling_3',
#  163: 'fueltype_gas',
#  164: 'aspiration_turbo',
#  165: 'doornumber_two',
#  166: 'carbody_hardtop',
#  167: 'carbody_hatchback',
#  168: 'carbody_sedan',
#  169: 'carbody_wagon',
#  170: 'drivewheel_fwd',
#  171: 'drivewheel_rwd',
#  172: 'enginelocation_rear',
#  173: 'enginetype_dohcv',
#  174: 'enginetype_l',
#  175: 'enginetype_ohc',
#  176: 'enginetype_ohcf',
#  177: 'enginetype_ohcv',
#  178: 'enginetype_rotor',
#  179: 'cylindernumber_five',
#  180: 'cylindernumber_four',
#  181: 'cylindernumber_six',
#  182: 'cylindernumber_three',
#  183: 'cylindernumber_twelve',
#  184: 'cylindernumber_two',
#  185: 'fuelsystem_2bbl',
#  186: 'fuelsystem_4bbl',
#  187: 'fuelsystem_idi',
#  188: 'fuelsystem_mfi',
#  189: 'fuelsystem_mpfi',
#  190: 'fuelsystem_spdi',
#  191: 'fuelsystem_spfi'}

# %%
# we normalize data because data has big vlaues in decimal and it will worsen performance of our model, may overfit 
# or  we may face hardware resource high usage
# we will apply the formula normalized_train_data = (train_data - mean)/ stadrad_deviation
# firt take mean of training, then subtract mean from each value of the array slice train_data.iloc[:,0:13]
mean = train_data.iloc[:,0:13].mean(axis=0) # taking the mean of 
train_data.iloc[:,0:13] -= mean
std = train_data.iloc[:,0:13].std(axis=0)
train_data.iloc[:,0:13] /= std
test_data.iloc[:,0:13] -= mean
test_data.iloc[:,0:13] /= std

# %%
mean
# Out:
# wheelbase          -5.855049e-15
# carlength           8.248721e-15
# carwidth            9.341621e-15
# carheight          -8.755801e-16
# curbweight         -2.913351e-16
# enginesize         -9.566815e-17
# boreratio          -2.587371e-15
# stroke              1.676319e-14
# compressionratio    4.747975e-16
# horsepower         -1.059043e-16
# peakrpm             5.370015e-16
# citympg             1.999976e-16
# highwaympg          1.968481e-16
# dtype: float64

# %%
std
# Out:
# wheelbase           1.0
# carlength           1.0
# carwidth            1.0
# carheight           1.0
# curbweight          1.0
# enginesize          1.0
# boreratio           1.0
# stroke              1.0
# compressionratio    1.0
# horsepower          1.0
# peakrpm             1.0
# citympg             1.0
# highwaympg          1.0
# dtype: float64

# %%
mean_label = train_label.mean()
train_label -= mean_label
std_label = train_label.std()
train_label /= std_label
test_label -= mean_label
test_label /= std_label

# %%
mean_label
# Out:
# 13379.132390070921

# %%
std_label
# Out:
# 8189.4945680106175

# %%
print(mean_label)
# Out:
# 13379.132390070921

# %%
test_label
# Out:
# 0      0.014148
# 10     0.372534
# 14     1.365880
# 15     2.122337
# 18    -1.004718
#          ...
# 192    0.056886
# 193   -0.132991
# 194   -0.053621
# 196    0.318196
# 198    0.615529
# Name: price, Length: 64, dtype: float64

# %%
train_data.shape
# Out:
# (141, 192)

# %% [markdown]
# store values in numpy array

# %%
test = np.array(test_data.iloc[:]).astype('float32')

# %%
train = np.array(train_data.iloc[:]).astype('float32')

# %%
test_l= np.array(test_label.astype('float32'))

# %%
train_l= np.array(train_label.astype('float32'))

# %%
train.shape[1]
# Out:
# 192

# %%
(141,192)[1]
# Out:
# 192

# %%
train.dtype
# Out:
# dtype('float32')

# %% [markdown]
# # Models section
# ```
# #WE will configure different models here according to relu, tanh , regularization, dropout etc..
# ```

# %%
# we are passing activation function as a parameter here so that we can call this function with tanh or relu while
# fitting and training the model
from keras import models
from keras import layers
def build_model(act):
  model = models.Sequential()
  model.add(layers.Dense(128, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dense(64, activation= act))
  model.add(layers.Dense(32, activation= act))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('relu').summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               24704
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Regularized model
from keras import regularizers
def build_model_regular(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001),input_shape=(train.shape[1],)))
  model.add(layers.Dense(8, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(6, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_regular('tanh').summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 10)                1930
# _________________________________________________________________
# dense_9 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_10 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %%
# dropout model
from keras import regularizers
def build_model_drop(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(8, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(6, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_drop('relu').summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 10)                1930
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_14 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # K Fold validation section
# ## here we will use len(train)//k to make 141//4 = 36 rows for validation in each validation test and collect the validation scores for relu , tanh , regularization , and dropout

# %%
#k fold validation with relu
# 141/4
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_relu = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_relu.append(val_mae)
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3

# %%
# 141/4
#k fold validation with tanh
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_tanh = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('tanh')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_tanh.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7f492800fdd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4928019e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4912faf950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f490d48c320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with regularization
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_regular = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_regular('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_regular.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f490f77cc20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f490c2c18c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f490b07c4d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f490b8d75f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with dropout
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_drop = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_drop('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=1)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=1)
  all_scores_drop.append(val_mae)
# Out:
# processing fold # 0
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.0990 - mae: 0.7762
# Epoch 2/100
# 106/106 [==============================] - 0s 976us/step - loss: 0.5788 - mae: 0.5939
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5204 - mae: 0.4991
# Epoch 4/100
# 106/106 [==============================] - 0s 957us/step - loss: 0.8586 - mae: 0.6124
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6134 - mae: 0.5272
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8021 - mae: 0.5782
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3312 - mae: 0.3660
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5247 - mae: 0.4742
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2512 - mae: 0.3417
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3893 - mae: 0.4486
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2582 - mae: 0.3623
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3036 - mae: 0.3538
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2753 - mae: 0.3378
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1757 - mae: 0.2800
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1971 - mae: 0.2954
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2283 - mae: 0.3693
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2789 - mae: 0.3336
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2733 - mae: 0.3355
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1694 - mae: 0.3010
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3730 - mae: 0.3453
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2238 - mae: 0.3091
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2975 - mae: 0.3363
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2820 - mae: 0.3486
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1712 - mae: 0.3012
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2489 - mae: 0.3375
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2643 - mae: 0.3373
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2962 - mae: 0.3027
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3018 - mae: 0.3246
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1958 - mae: 0.2874
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2398 - mae: 0.3158
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3499 - mae: 0.3500
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5652 - mae: 0.4828
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2622 - mae: 0.3317
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2230 - mae: 0.3098
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2612 - mae: 0.3148
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2078 - mae: 0.3185
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2957 - mae: 0.3015
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5440 - mae: 0.4495
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1740 - mae: 0.2685
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1425 - mae: 0.2332
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1551 - mae: 0.2693
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3085 - mae: 0.3370
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3457 - mae: 0.3108
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1440 - mae: 0.2752
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2486 - mae: 0.2850
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1309 - mae: 0.2281
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3104 - mae: 0.3408
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2013 - mae: 0.2605
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1442 - mae: 0.2709
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2439 - mae: 0.2913
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2008 - mae: 0.3063
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1499 - mae: 0.2638
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1722 - mae: 0.2586
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2182 - mae: 0.2999
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1382 - mae: 0.2549
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1906 - mae: 0.2782
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2497 - mae: 0.3325
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2842 - mae: 0.3358
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3267 - mae: 0.3557
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3017 - mae: 0.2900
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2853 - mae: 0.2951
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6114 - mae: 0.3623
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1273 - mae: 0.2487
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1015 - mae: 0.2100
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3071 - mae: 0.3186
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2434 - mae: 0.3041
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3130 - mae: 0.3152
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2761 - mae: 0.3107
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2029 - mae: 0.2757
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7732 - mae: 0.3871
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1404 - mae: 0.2680
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1566 - mae: 0.2461
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1862 - mae: 0.2523
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2592 - mae: 0.2971
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1807 - mae: 0.2543
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2043 - mae: 0.2773
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1334 - mae: 0.2618
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1963 - mae: 0.2760
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1759 - mae: 0.2816
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1291 - mae: 0.2344
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3480 - mae: 0.3553
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1985 - mae: 0.2804
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4453 - mae: 0.3474
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3074 - mae: 0.3470
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0924 - mae: 0.2192
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4000 - mae: 0.3571
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1164 - mae: 0.2111
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2087 - mae: 0.2828
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1449 - mae: 0.2557
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1608 - mae: 0.2669
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1503 - mae: 0.2321
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1311 - mae: 0.2542
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2573 - mae: 0.3082
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3051 - mae: 0.3463
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1030 - mae: 0.2185
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2147 - mae: 0.3061
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1060 - mae: 0.2306
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1731 - mae: 0.2607
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2562 - mae: 0.2754
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1220 - mae: 0.2418
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f490b8d7560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3026 - mae: 0.3749
# processing fold # 1
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.5214 - mae: 0.5596
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4431 - mae: 0.4469
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3625 - mae: 0.4134
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5180 - mae: 0.4553
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3837 - mae: 0.4037
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5358 - mae: 0.5033
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5864 - mae: 0.5070
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5426 - mae: 0.4462
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3455 - mae: 0.3960
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2635 - mae: 0.3412
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3452 - mae: 0.3903
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3081 - mae: 0.4055
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3061 - mae: 0.3793
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3586 - mae: 0.3930
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2201 - mae: 0.3477
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3584 - mae: 0.3956
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3152 - mae: 0.3584
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4201 - mae: 0.3803
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2659 - mae: 0.3503
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3148 - mae: 0.3873
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2310 - mae: 0.3265
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3307 - mae: 0.3929
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2335 - mae: 0.3573
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4242 - mae: 0.4262
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2747 - mae: 0.3480
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1927 - mae: 0.3147
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3782 - mae: 0.3536
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2612 - mae: 0.3386
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2684 - mae: 0.3129
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3164 - mae: 0.3594
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1903 - mae: 0.2827
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2281 - mae: 0.3249
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1413 - mae: 0.2719
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2598 - mae: 0.3565
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1770 - mae: 0.2802
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2305 - mae: 0.3286
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2822 - mae: 0.3433
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2199 - mae: 0.3122
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2073 - mae: 0.3476
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3854 - mae: 0.3777
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4121 - mae: 0.3853
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2505 - mae: 0.2878
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3553 - mae: 0.3274
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2214 - mae: 0.3195
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2767 - mae: 0.3547
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4128 - mae: 0.3731
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2283 - mae: 0.3066
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2090 - mae: 0.2956
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2845 - mae: 0.3367
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2099 - mae: 0.3254
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1973 - mae: 0.3195
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2288 - mae: 0.2765
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2471 - mae: 0.2992
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1676 - mae: 0.2618
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2337 - mae: 0.2974
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1578 - mae: 0.2421
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1610 - mae: 0.2784
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2861 - mae: 0.3489
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2927 - mae: 0.2980
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3225 - mae: 0.3288
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1274 - mae: 0.2586
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2505 - mae: 0.3223
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1942 - mae: 0.2975
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2736 - mae: 0.2950
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2191 - mae: 0.3021
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2490 - mae: 0.2839
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3869 - mae: 0.3260
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1796 - mae: 0.2973
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2048 - mae: 0.2664
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2765 - mae: 0.3214
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0972 - mae: 0.2378
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3068 - mae: 0.3771
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2014 - mae: 0.2960
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1324 - mae: 0.2886
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2513 - mae: 0.3068
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2632 - mae: 0.3247
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3418 - mae: 0.3591
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1512 - mae: 0.2873
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2031 - mae: 0.2702
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1610 - mae: 0.2926
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1511 - mae: 0.2699
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1541 - mae: 0.2673
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1262 - mae: 0.2621
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1663 - mae: 0.2844
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2041 - mae: 0.2862
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3268 - mae: 0.3074
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4299 - mae: 0.3425
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1657 - mae: 0.2381
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1002 - mae: 0.2273
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1765 - mae: 0.2943
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2542 - mae: 0.3132
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1327 - mae: 0.2802
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1380 - mae: 0.2579
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1744 - mae: 0.2723
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1609 - mae: 0.2836
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1738 - mae: 0.2688
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1451 - mae: 0.2524
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1783 - mae: 0.2698
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1144 - mae: 0.2204
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1974 - mae: 0.3033
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f490b8d7680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4885 - mae: 0.4294
# processing fold # 2
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.9023 - mae: 0.7009
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0048 - mae: 0.6423
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9209 - mae: 0.6246
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8873 - mae: 0.6856
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7031 - mae: 0.5261
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4055 - mae: 0.4460
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3393 - mae: 0.4434
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8304 - mae: 0.5183
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4472 - mae: 0.4434
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7061 - mae: 0.5086
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6178 - mae: 0.4996
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7577 - mae: 0.5624
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3735 - mae: 0.4124
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4663 - mae: 0.4314
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3456 - mae: 0.3301
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2231 - mae: 0.3241
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2443 - mae: 0.3139
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5050 - mae: 0.4321
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2761 - mae: 0.3446
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3092 - mae: 0.3758
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5107 - mae: 0.4684
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2287 - mae: 0.3036
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7797 - mae: 0.5005
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2373 - mae: 0.3542
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2703 - mae: 0.3915
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3163 - mae: 0.3538
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3009 - mae: 0.3256
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2722 - mae: 0.3712
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2497 - mae: 0.3355
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2446 - mae: 0.3214
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4361 - mae: 0.4150
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4103 - mae: 0.3808
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5773 - mae: 0.4909
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2528 - mae: 0.3244
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5853 - mae: 0.4229
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2195 - mae: 0.3309
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2626 - mae: 0.3431
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1800 - mae: 0.3116
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3687 - mae: 0.3601
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4008 - mae: 0.3653
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2249 - mae: 0.3011
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3062 - mae: 0.3344
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2063 - mae: 0.3099
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1919 - mae: 0.2644
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2813 - mae: 0.2701
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2330 - mae: 0.3298
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2860 - mae: 0.3067
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3173 - mae: 0.3761
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2512 - mae: 0.3596
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2124 - mae: 0.2999
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2499 - mae: 0.2259
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1391 - mae: 0.2588
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3561 - mae: 0.3153
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2871 - mae: 0.2894
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3270 - mae: 0.3853
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2541 - mae: 0.2953
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5183 - mae: 0.3690
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1692 - mae: 0.2597
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5002 - mae: 0.3795
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6957 - mae: 0.4420
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4521 - mae: 0.3810
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3970 - mae: 0.3980
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3745 - mae: 0.3494
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1479 - mae: 0.2603
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4842 - mae: 0.4048
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2555 - mae: 0.3110
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6359 - mae: 0.4609
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2594 - mae: 0.3165
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2985 - mae: 0.3364
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3686 - mae: 0.3111
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3209 - mae: 0.3314
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2981 - mae: 0.3391
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3440 - mae: 0.3356
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3173 - mae: 0.2991
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3119 - mae: 0.3066
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2363 - mae: 0.3160
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3660 - mae: 0.3429
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1844 - mae: 0.2978
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2893 - mae: 0.3517
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2084 - mae: 0.2939
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2745 - mae: 0.3630
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4334 - mae: 0.3610
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3973 - mae: 0.3600
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4699 - mae: 0.3855
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3383 - mae: 0.3376
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3030 - mae: 0.3345
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1915 - mae: 0.2487
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2043 - mae: 0.2938
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2351 - mae: 0.2868
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2953 - mae: 0.3406
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3065 - mae: 0.3117
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1198 - mae: 0.2266
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1425 - mae: 0.2643
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1483 - mae: 0.2625
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4023 - mae: 0.3335
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2135 - mae: 0.2965
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5395 - mae: 0.3692
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4738 - mae: 0.3863
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2015 - mae: 0.3014
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1839 - mae: 0.2523
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f490d4ebb90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3390 - mae: 0.4146
# processing fold # 3
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.2060 - mae: 0.8591
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8103 - mae: 0.7317
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6132 - mae: 0.6633
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6009 - mae: 0.5666
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5540 - mae: 0.5357
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6269 - mae: 0.5676
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4598 - mae: 0.4574
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3059 - mae: 0.3987
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2962 - mae: 0.3960
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7494 - mae: 0.5736
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4088 - mae: 0.4538
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4876 - mae: 0.4512
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3784 - mae: 0.3891
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6136 - mae: 0.4553
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2991 - mae: 0.3644
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6869 - mae: 0.4683
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4200 - mae: 0.4176
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2417 - mae: 0.3544
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3300 - mae: 0.3984
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6561 - mae: 0.4915
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6288 - mae: 0.4777
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3800 - mae: 0.4402
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3496 - mae: 0.3820
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5930 - mae: 0.4549
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4649 - mae: 0.3805
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3633 - mae: 0.3855
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2843 - mae: 0.3505
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7330 - mae: 0.5219
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3764 - mae: 0.3483
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2153 - mae: 0.2962
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2083 - mae: 0.2780
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3032 - mae: 0.3722
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1781 - mae: 0.2907
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4109 - mae: 0.4357
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3139 - mae: 0.3569
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2108 - mae: 0.3369
# Epoch 37/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3557 - mae: 0.3908
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2478 - mae: 0.3257
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2747 - mae: 0.3552
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2179 - mae: 0.3039
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2829 - mae: 0.3262
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1865 - mae: 0.2879
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2372 - mae: 0.3420
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2918 - mae: 0.3238
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1797 - mae: 0.2448
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2720 - mae: 0.3240
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2659 - mae: 0.3429
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3599 - mae: 0.3679
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4116 - mae: 0.3956
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1951 - mae: 0.3117
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2625 - mae: 0.3024
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1550 - mae: 0.2816
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1517 - mae: 0.2708
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1476 - mae: 0.2774
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2070 - mae: 0.3256
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1855 - mae: 0.2661
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1982 - mae: 0.3081
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1641 - mae: 0.2602
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1949 - mae: 0.2810
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1842 - mae: 0.2886
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1941 - mae: 0.2969
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2390 - mae: 0.3093
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1801 - mae: 0.2864
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5351 - mae: 0.3802
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3147 - mae: 0.3508
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3299 - mae: 0.2893
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2640 - mae: 0.3126
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2522 - mae: 0.2994
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2428 - mae: 0.3144
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2714 - mae: 0.3507
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4795 - mae: 0.4336
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2303 - mae: 0.3072
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2040 - mae: 0.2865
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2701 - mae: 0.3155
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1922 - mae: 0.2849
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1414 - mae: 0.2676
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1813 - mae: 0.2735
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1163 - mae: 0.2561
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2482 - mae: 0.3109
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2637 - mae: 0.3085
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2260 - mae: 0.2581
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1530 - mae: 0.2545
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1190 - mae: 0.2196
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2082 - mae: 0.2983
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1565 - mae: 0.2575
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2895 - mae: 0.3046
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1785 - mae: 0.2799
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1468 - mae: 0.2474
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2283 - mae: 0.2646
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1813 - mae: 0.2866
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1080 - mae: 0.2233
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1847 - mae: 0.2881
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1510 - mae: 0.2617
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1117 - mae: 0.2535
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3068 - mae: 0.2850
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1989 - mae: 0.2772
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2257 - mae: 0.2900
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2351 - mae: 0.2845
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1224 - mae: 0.2415
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1312 - mae: 0.2537
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f490b038dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0731 - mae: 0.1990

# %% [markdown]
# # Scores
# ## here we will see  MAE mean absolute Error scores of all model which we have saved in the list during each training in above section

# %%
all_scores_relu
# Out:
# [0.3039321005344391,
#  0.2650308310985565,
#  0.3521471619606018,
#  0.29601386189460754]

# %%
all_scores_tanh
# Out:
# [0.3259147107601166,
#  0.29587411880493164,
#  0.4682053029537201,
#  0.25521421432495117]

# %%
all_scores_regular
# Out:
# [0.2819159924983978, 0.207330584526062, 0.3681083917617798, 0.276273250579834]

# %%
all_scores_drop
# Out:
# [0.3748636841773987,
#  0.4293506443500519,
#  0.41457223892211914,
#  0.19904570281505585]

# %% [markdown]
# # training on the training data
# ## here we will call each model separately from Models section and train on the training data and evaluate on the test data

# %%
model_tanh = build_model('tanh')
model_tanh.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_tanh.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f490d497b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0924 - mae: 0.2374

# %%
model_relu = build_model('relu')
model_relu.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_relu.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f490cb4b710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0904 - mae: 0.2421

# %%
model_regular = build_model_regular('relu')
model_regular.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_regular.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f49130da4d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1275 - mae: 0.2312

# %%
model_drop = build_model_drop('relu')
model_drop.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_drop.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f49130da5f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1504 - mae: 0.2569

# %% [markdown]
# # Prediction Section
# ## here we will predict our prices of our test dataset with each model which we have trained in training section
# ## Note that here we will use the reverse process of Normalization to retrieve our values of price in thousand of dollars i.e. x = (y - mean)/ std ==>> we will calculate( y = x * std + mean) and then we will compare it with our target values

# %%
test_l
# Out:
# array([ 0.01414832,  0.3725343 ,  1.3658801 ,  2.122337  , -1.004718  ,
#        -0.7045773 , -0.5886972 , -0.97443527, -0.763189  , -0.52312535,
#        -0.05301089, -0.3704908 , -0.5449216 , -0.80397296, -0.5536523 ,
#        -0.26059392,  0.6062484 ,  1.4864004 ,  2.5404336 ,  3.367835  ,
#        -0.8779702 , -0.09159691,  0.18192424, -0.7802841 , -0.50065756,
#        -0.9622245 , -0.6813769 , -0.5409531 ,  0.01463675,  0.12453365,
#         0.46643507, -0.1806134 ,  0.2687428 ,  0.4299249 ,  0.45129374,
#        -0.07511237,  2.3382235 ,  2.200547  , -0.49870384,  0.20280465,
#         0.26019526, -0.68430746, -0.7224051 , -0.65524584, -0.98066276,
#        -0.7889537 , -0.7547636 , -0.6888255 , -0.6277716 , -0.4983375 ,
#        -0.6020069 , -0.4139611 , -0.22347318, -0.54107517,  0.28217462,
#        -0.68430746, -0.6574438 , -0.59638995, -0.01027321,  0.056886  ,
#        -0.1329914 , -0.05362143,  0.3181964 ,  0.6155285 ], dtype=float32)

# %%
def predict(model, m):
  print(f" The Actual value Price was : {test_l[m]* std_label + mean_label} " )
  return(f" The Predicted Price was : {(model.predict(test[m:m+1].reshape(1,test.shape[1]))) * std_label + mean_label} ")

# %%
x_tanh = predict(model_tanh,2)
x_tanh
# Out:
#  The Actual value Price was : 24565.000309357743
# ' The Predicted Price was : [[19702.055]] '

# %%
x_relu = predict(model_relu,2)
x_relu
# Out:
#  The Actual value Price was : 24565.000309357743
# ' The Predicted Price was : [[22452.867]] '

# %%
x_regular = predict(model_regular,2)
x_regular
# Out:
#  The Actual value Price was : 24565.000309357743
# ' The Predicted Price was : [[21780.67]] '

# %%
x_drop = predict(model_drop,2)
x_drop
# Out:
#  The Actual value Price was : 24565.000309357743
# ' The Predicted Price was : [[19474.963]] '

# %%
def plot_fn(mod):
  y_true = test_l* std_label + mean_label
  y_pred = mod.predict(test) * std_label + mean_label
  return y_true , y_pred.flatten()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
def plotting(mod, label):
  y_true, y_pred = plot_fn(mod)
  coef = np.polyfit(y_true,y_pred,1)
  poly1d_fn = np.poly1d(coef) 
  # poly1d_fn is now a function which takes in x and returns an estimate for y
  plt.figure()
  plt.plot(y_true,y_pred, 'yo', y_true, poly1d_fn(y_true), '--k')
  plt.title(label)
  plt.xlabel('Thousand Dollar True' )
  plt.ylabel('Thousand Dollar Predictions' )
  plt.xlim(0, 50000)
  plt.ylim(0, 50000)

# %%
plot_list = []
for i,j in enumerate([model_relu, model_tanh, model_regular, model_drop]):
  list_name = ['model_relu', 'model_tanh', 'model_regular', 'model_drop']
  plot_list.append(plotting(j,list_name[i]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f490b07c3b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f49112275f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4913a51050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4911227290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
